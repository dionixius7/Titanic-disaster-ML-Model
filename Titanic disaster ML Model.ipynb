# %%
import pandas as pd
import numpy as np
import random as rnd

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import confusion_matrix


print('Loaded')
# Out:
# Loaded

# %% [markdown]
# # Data Introduction

# %%
train = pd.read_csv('/kaggle/input/titanic/train.csv') 
test = pd.read_csv('/kaggle/input/titanic/test.csv')

# %%
train.info()
print('_'*40)
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# ________________________________________
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %% [markdown]
# ## Keterangan
# * Survived: 0 = No, 1 = Yes
# * pclass: Jenis kelas 1 = 1st, 2 = 2nd, 3 = 3rd
# * sibsp: # of siblings / spouses aboard the Titanic
# * parch: # of parents / children aboard the Titanic
# * ticket: Nomor tiket
# * cabin: Nomor kabin
# * embarked: Asal keberangkatan C = Cherbourg, Q = Queenstown, S = Southampton

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %%
train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
train[['Sex', 'Survived']].groupby(['Sex'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
train[['Parch', 'Survived']].groupby(['Parch'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Parch  Survived
# 3      3  0.600000
# 1      1  0.550847
# 2      2  0.500000
# 0      0  0.343658
# 5      5  0.200000
# 4      4  0.000000
# 6      6  0.000000

# %%
train[['SibSp', 'Survived']].groupby(['SibSp'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    SibSp  Survived
# 1      1  0.535885
# 2      2  0.464286
# 0      0  0.345395
# 3      3  0.250000
# 4      4  0.166667
# 5      5  0.000000
# 6      8  0.000000

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
test.isnull().sum()
test["Survived"] = ""
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
#     Survived
# 0
# 1
# 2
# 3
# 4
# ..       ...
# 413
# 414
# 415
# 416
# 417
#
# [418 rows x 12 columns]

# %% [markdown]
# # Data Visualization

# %%
def bar_chart(feature):
    survived = train[train['Survived']==1][feature].value_counts().sort_index()
    dead = train[train['Survived']==0][feature].value_counts().sort_index()
    
    df_survived = pd.DataFrame({feature: survived.index, 'Survived': survived.values})
    df_dead = pd.DataFrame({feature: dead.index, 'Dead': dead.values})

    fig, ax = plt.subplots(1, 2, figsize=(14, 5), sharey=True)
    
    sns.barplot(data=df_survived, x=feature, y='Survived', ax=ax[0], color='green')
    ax[0].set_title(f'Survived by {feature}')
    
    sns.barplot(data=df_dead, x=feature, y='Dead', ax=ax[1], color='red')
    ax[1].set_title(f'Dead by {feature}')
    
    plt.show()

# %%
bar_chart('Sex')
print("Survived :\n",train[train['Survived']==1]['Sex'].value_counts())
print("Dead:\n",train[train['Survived']==0]['Sex'].value_counts())

#probabilitas bertahan hidup paling tinggi yaitu perempuan
# Out:
# Survived :
#  female    233
# male      109
# Name: Sex, dtype: int64
# Dead:
#  male      468
# female     81
# Name: Sex, dtype: int64

# %%
bar_chart('Pclass')
print("Survived :\n",train[train['Survived']==1]['Pclass'].value_counts())
print("Dead:\n",train[train['Survived']==0]['Pclass'].value_counts())

#probabilitas bertahan hidup paling tinggi berada di penumpang kelas 1
# Out:
# Survived :
#  1    136
# 3    119
# 2     87
# Name: Pclass, dtype: int64
# Dead:
#  3    372
# 2     97
# 1     80
# Name: Pclass, dtype: int64

# %%
bar_chart('SibSp')
print("Survived :\n",train[train['Survived']==1]['SibSp'].value_counts())
print("Dead:\n",train[train['Survived']==0]['SibSp'].value_counts())

#penumpang yang tidak bersama kerabat memiliki probabilitas bertahan hidup lebih tinggi
# Out:
# Survived :
#  0    210
# 1    112
# 2     13
# 3      4
# 4      3
# Name: SibSp, dtype: int64
# Dead:
#  0    398
# 1     97
# 4     15
# 2     15
# 3     12
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
bar_chart('Parch')
print("Survived :\n",train[train['Survived']==1]['Parch'].value_counts())
print("Dead:\n",train[train['Survived']==0]['Parch'].value_counts())

#penumpang yang berlayar bersama 2 orang tua atau anak memiliki probabilitas bertahan hidup lebih tinggi
# Out:
# Survived :
#  0    233
# 1     65
# 2     40
# 3      3
# 5      1
# Name: Parch, dtype: int64
# Dead:
#  0    445
# 1     53
# 2     40
# 5      4
# 4      4
# 3      2
# 6      1
# Name: Parch, dtype: int64

# %%
bar_chart('Embarked')
print("Survived :\n",train[train['Survived']==1]['Embarked'].value_counts())
print("Dead:\n",train[train['Survived']==0]['Embarked'].value_counts())

#penumpang yang memiliki probabilitas bertahan hidup lebih tinggi adalah yang keberangkatan dari C
# Out:
# Survived :
#  S    217
# C     93
# Q     30
# Name: Embarked, dtype: int64
# Dead:
#  S    427
# C     75
# Q     47
# Name: Embarked, dtype: int64

# %% [markdown]
# # Feature Engineering

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
train_test_data = [train, test]

for dataset in train_test_data:
    dataset['Title'] = dataset['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)

# %%
train['Title'].value_counts()
# Out:
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Major         2
# Mlle          2
# Col           2
# Sir           1
# Lady          1
# Capt          1
# Jonkheer      1
# Ms            1
# Don           1
# Mme           1
# Countess      1
# Name: Title, dtype: int64

# %%
test['Title'].value_counts()
# Out:
# Mr        240
# Miss       78
# Mrs        72
# Master     21
# Col         2
# Rev         2
# Ms          1
# Dona        1
# Dr          1
# Name: Title, dtype: int64

# %% [markdown]
# ### agar mempermudah analisa
# ### status gender, pernikahan dsb akan dibuat ke dalam kode

# %%
title_mapping = {"Mr": 0, "Miss": 1, "Mrs": 2, 
                 "Master": 3, "Dr": 3, "Rev": 3, "Col": 3, "Major": 3, "Mlle": 3,"Countess": 3,
                 "Ms": 3, "Lady": 3, "Jonkheer": 3, "Don": 3, "Dona" : 3, "Mme": 3,"Capt": 3,"Sir": 3 }

for dataset in train_test_data:
    dataset['Title'] = dataset["Title"].map(title_mapping)

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
#     Survived  Title
# 0                 0
# 1                 2
# 2                 0
# 3                 0
# 4                 2
# ..       ...    ...
# 413               0
# 414               3
# 415               0
# 416               0
# 417               3
#
# [418 rows x 13 columns]

# %%
bar_chart('Title')

# %%
train.drop('Name', axis=1, inplace=True)
test.drop('Name', axis=1, inplace=True)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Title
# 0         A/5 21171   7.2500   NaN        S      0
# 1          PC 17599  71.2833   C85        C      2
# 2  STON/O2. 3101282   7.9250   NaN        S      1
# 3            113803  53.1000  C123        S      2
# 4            373450   8.0500   NaN        S      0

# %%
sex_mapping = {"male": 0, "female": 1}
for dataset in train_test_data:
    dataset['Sex'] = dataset['Sex'].map(sex_mapping)
    
bar_chart('Sex')

# %%
test.head()
# Out:
#    PassengerId  Pclass  Sex   Age  SibSp  Parch   Ticket     Fare Cabin  \
# 0          892       3    0  34.5      0      0   330911   7.8292   NaN
# 1          893       3    1  47.0      1      0   363272   7.0000   NaN
# 2          894       2    0  62.0      0      0   240276   9.6875   NaN
# 3          895       3    0  27.0      0      0   315154   8.6625   NaN
# 4          896       3    1  22.0      1      1  3101298  12.2875   NaN
#
#   Embarked Survived  Title
# 0        Q               0
# 1        S               2
# 2        Q               0
# 3        S               0
# 4        S               2

# %%
train["Age"].fillna(train.groupby("Title")["Age"].transform("median"), inplace= True)
test["Age"].fillna(test.groupby('Title')['Age'].transform("median"), inplace= True)

# %%
train.head(30)
# Out:
#     PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch            Ticket  \
# 0             1         0       3    0  22.0      1      0         A/5 21171
# 1             2         1       1    1  38.0      1      0          PC 17599
# 2             3         1       3    1  26.0      0      0  STON/O2. 3101282
# 3             4         1       1    1  35.0      1      0            113803
# 4             5         0       3    0  35.0      0      0            373450
# 5             6         0       3    0  30.0      0      0            330877
# 6             7         0       1    0  54.0      0      0             17463
# 7             8         0       3    0   2.0      3      1            349909
# 8             9         1       3    1  27.0      0      2            347742
# 9            10         1       2    1  14.0      1      0            237736
# 10           11         1       3    1   4.0      1      1           PP 9549
# 11           12         1       1    1  58.0      0      0            113783
# 12           13         0       3    0  20.0      0      0         A/5. 2151
# 13           14         0       3    0  39.0      1      5            347082
# 14           15         0       3    1  14.0      0      0            350406
# 15           16         1       2    1  55.0      0      0            248706
# 16           17         0       3    0   2.0      4      1            382652
# 17           18         1       2    0  30.0      0      0            244373
# 18           19         0       3    1  31.0      1      0            345763
# 19           20         1       3    1  35.0      0      0              2649
# 20           21         0       2    0  35.0      0      0            239865
# 21           22         1       2    0  34.0      0      0            248698
# 22           23         1       3    1  15.0      0      0            330923
# 23           24         1       1    0  28.0      0      0            113788
# 24           25         0       3    1   8.0      3      1            349909
# 25           26         1       3    1  38.0      1      5            347077
# 26           27         0       3    0  30.0      0      0              2631
# 27           28         0       1    0  19.0      3      2             19950
# 28           29         1       3    1  21.0      0      0            330959
# 29           30         0       3    0  30.0      0      0            349216
#
#         Fare        Cabin Embarked  Title
# 0     7.2500          NaN        S      0
# 1    71.2833          C85        C      2
# 2     7.9250          NaN        S      1
# 3    53.1000         C123        S      2
# 4     8.0500          NaN        S      0
# 5     8.4583          NaN        Q      0
# 6    51.8625          E46        S      0
# 7    21.0750          NaN        S      3
# 8    11.1333          NaN        S      2
# 9    30.0708          NaN        C      2
# 10   16.7000           G6        S      1
# 11   26.5500         C103        S      1
# 12    8.0500          NaN        S      0
# 13   31.2750          NaN        S      0
# 14    7.8542          NaN        S      1
# 15   16.0000          NaN        S      2
# 16   29.1250          NaN        Q      3
# 17   13.0000          NaN        S      0
# 18   18.0000          NaN        S      2
# 19    7.2250          NaN        C      2
# 20   26.0000          NaN        S      0
# 21   13.0000          D56        S      0
# 22    8.0292          NaN        Q      1
# 23   35.5000           A6        S      0
# 24   21.0750          NaN        S      1
# 25   31.3875          NaN        S      2
# 26    7.2250          NaN        C      0
# 27  263.0000  C23 C25 C27        S      0
# 28    7.8792          NaN        Q      1
# 29    7.8958          NaN        S      0

# %%
facet = sns.FacetGrid(train, hue="Survived", aspect=4)
facet.map(sns.kdeplot,'Age', shade=True)
facet.set(xlim=(0, train['Age'].max()))
facet.add_legend() 
plt.show()

#dari grafik ini terlihat rentang umur 20-30an lebih mampu bertahan hidup namun banyak juga yang wafat

# %%
train.info()
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Sex            891 non-null int64
# Age            891 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# Title          891 non-null int64
# dtypes: float64(2), int64(7), object(3)
# memory usage: 83.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Sex            418 non-null int64
# Age            418 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# Survived       418 non-null object
# Title          418 non-null int64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 39.3+ KB

# %% [markdown]
# ### Mengubah status level umur menjadi angka
# ### child:0, young:1, adult:2, mid-age:3, senior:4

# %%
for dataset in train_test_data:
    dataset.loc[dataset['Age'] <= 16, 'Age'] = 0
    dataset.loc[(dataset['Age'] > 16) & (dataset['Age'] <= 26), 'Age'] = 1
    dataset.loc[(dataset['Age'] > 26) & (dataset['Age'] <= 36), 'Age'] = 2
    dataset.loc[(dataset['Age'] > 36) & (dataset['Age'] <= 62), 'Age'] = 3
    dataset.loc[dataset['Age'] > 62, 'Age'] = 4
    
bar_chart('Age')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  1.0      1      0         A/5 21171
# 1            2         1       1    1  3.0      1      0          PC 17599
# 2            3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  2.0      1      0            113803
# 4            5         0       3    0  2.0      0      0            373450
#
#       Fare Cabin Embarked  Title
# 0   7.2500   NaN        S      0
# 1  71.2833   C85        C      2
# 2   7.9250   NaN        S      1
# 3  53.1000  C123        S      2
# 4   8.0500   NaN        S      0

# %%
Pclass1 = train[train['Pclass'] == 1]['Embarked'].value_counts().sort_index()
Pclass2 = train[train['Pclass'] == 2]['Embarked'].value_counts().sort_index()
Pclass3 = train[train['Pclass'] == 3]['Embarked'].value_counts().sort_index()

df_pclass = pd.DataFrame({
    'Embarked': Pclass1.index,
    '1st Class': Pclass1.values,
    '2nd Class': Pclass2.values,
    '3rd Class': Pclass3.values
})

df_pclass.plot(kind='bar', x='Embarked', figsize=(10, 5))
plt.title('Embarked by Pclass')
plt.show()
print("Pclass1:\n", Pclass1)
print("Pclass2:\n", Pclass2)
print("Pclass3:\n", Pclass3)
# Out:
# Pclass1:
#  C     85
# Q      2
# S    127
# Name: Embarked, dtype: int64
# Pclass2:
#  C     17
# Q      3
# S    164
# Name: Embarked, dtype: int64
# Pclass3:
#  C     66
# Q     72
# S    353
# Name: Embarked, dtype: int64

# %%
for dataset in train_test_data:
    dataset['Embarked'] =  dataset['Embarked'].fillna('S')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  1.0      1      0         A/5 21171
# 1            2         1       1    1  3.0      1      0          PC 17599
# 2            3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  2.0      1      0            113803
# 4            5         0       3    0  2.0      0      0            373450
#
#       Fare Cabin Embarked  Title
# 0   7.2500   NaN        S      0
# 1  71.2833   C85        C      2
# 2   7.9250   NaN        S      1
# 3  53.1000  C123        S      2
# 4   8.0500   NaN        S      0

# %%
embarked_mapping = {'S': 0, 'C': 1, 'Q': 2}
for dataset in train_test_data:
    dataset['Embarked'] = dataset['Embarked'].map(embarked_mapping)
    
train["Fare"].fillna(train.groupby("Pclass")["Fare"].transform("median"), inplace=True)
test["Fare"].fillna(test.groupby("Pclass")["Fare"].transform("median"), inplace=True)
train.head(50)
# Out:
#     PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0             1         0       3    0  1.0      1      0         A/5 21171
# 1             2         1       1    1  3.0      1      0          PC 17599
# 2             3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3             4         1       1    1  2.0      1      0            113803
# 4             5         0       3    0  2.0      0      0            373450
# 5             6         0       3    0  2.0      0      0            330877
# 6             7         0       1    0  3.0      0      0             17463
# 7             8         0       3    0  0.0      3      1            349909
# 8             9         1       3    1  2.0      0      2            347742
# 9            10         1       2    1  0.0      1      0            237736
# 10           11         1       3    1  0.0      1      1           PP 9549
# 11           12         1       1    1  3.0      0      0            113783
# 12           13         0       3    0  1.0      0      0         A/5. 2151
# 13           14         0       3    0  3.0      1      5            347082
# 14           15         0       3    1  0.0      0      0            350406
# 15           16         1       2    1  3.0      0      0            248706
# 16           17         0       3    0  0.0      4      1            382652
# 17           18         1       2    0  2.0      0      0            244373
# 18           19         0       3    1  2.0      1      0            345763
# 19           20         1       3    1  2.0      0      0              2649
# 20           21         0       2    0  2.0      0      0            239865
# 21           22         1       2    0  2.0      0      0            248698
# 22           23         1       3    1  0.0      0      0            330923
# 23           24         1       1    0  2.0      0      0            113788
# 24           25         0       3    1  0.0      3      1            349909
# 25           26         1       3    1  3.0      1      5            347077
# 26           27         0       3    0  2.0      0      0              2631
# 27           28         0       1    0  1.0      3      2             19950
# 28           29         1       3    1  1.0      0      0            330959
# 29           30         0       3    0  2.0      0      0            349216
# 30           31         0       1    0  3.0      0      0          PC 17601
# 31           32         1       1    1  2.0      1      0          PC 17569
# 32           33         1       3    1  1.0      0      0            335677
# 33           34         0       2    0  4.0      0      0        C.A. 24579
# 34           35         0       1    0  2.0      1      0          PC 17604
# 35           36         0       1    0  3.0      1      0            113789
# 36           37         1       3    0  2.0      0      0              2677
# 37           38         0       3    0  1.0      0      0        A./5. 2152
# 38           39         0       3    1  1.0      2      0            345764
# 39           40         1       3    1  0.0      1      0              2651
# 40           41         0       3    1  3.0      1      0              7546
# 41           42         0       2    1  2.0      1      0             11668
# 42           43         0       3    0  2.0      0      0            349253
# 43           44         1       2    1  0.0      1      2     SC/Paris 2123
# 44           45         1       3    1  1.0      0      0            330958
# 45           46         0       3    0  2.0      0      0   S.C./A.4. 23567
# 46           47         0       3    0  2.0      1      0            370371
# 47           48         1       3    1  1.0      0      0             14311
# 48           49         0       3    0  2.0      2      0              2662
# 49           50         0       3    1  1.0      1      0            349237
#
#         Fare        Cabin  Embarked  Title
# 0     7.2500          NaN         0      0
# 1    71.2833          C85         1      2
# 2     7.9250          NaN         0      1
# 3    53.1000         C123         0      2
# 4     8.0500          NaN         0      0
# 5     8.4583          NaN         2      0
# 6    51.8625          E46         0      0
# 7    21.0750          NaN         0      3
# 8    11.1333          NaN         0      2
# 9    30.0708          NaN         1      2
# 10   16.7000           G6         0      1
# 11   26.5500         C103         0      1
# 12    8.0500          NaN         0      0
# 13   31.2750          NaN         0      0
# 14    7.8542          NaN         0      1
# 15   16.0000          NaN         0      2
# 16   29.1250          NaN         2      3
# 17   13.0000          NaN         0      0
# 18   18.0000          NaN         0      2
# 19    7.2250          NaN         1      2
# 20   26.0000          NaN         0      0
# 21   13.0000          D56         0      0
# 22    8.0292          NaN         2      1
# 23   35.5000           A6         0      0
# 24   21.0750          NaN         0      1
# 25   31.3875          NaN         0      2
# 26    7.2250          NaN         1      0
# 27  263.0000  C23 C25 C27         0      0
# 28    7.8792          NaN         2      1
# 29    7.8958          NaN         0      0
# 30   27.7208          NaN         1      3
# 31  146.5208          B78         1      2
# 32    7.7500          NaN         2      1
# 33   10.5000          NaN         0      0
# 34   82.1708          NaN         1      0
# 35   52.0000          NaN         0      0
# 36    7.2292          NaN         1      0
# 37    8.0500          NaN         0      0
# 38   18.0000          NaN         0      1
# 39   11.2417          NaN         1      1
# 40    9.4750          NaN         0      2
# 41   21.0000          NaN         0      2
# 42    7.8958          NaN         1      0
# 43   41.5792          NaN         1      1
# 44    7.8792          NaN         2      1
# 45    8.0500          NaN         0      0
# 46   15.5000          NaN         2      0
# 47    7.7500          NaN         2      1
# 48   21.6792          NaN         1      0
# 49   17.8000          NaN         0      2

# %%
facet = sns.FacetGrid(train, hue="Survived", aspect=4 )
facet.map(sns.kdeplot, 'Fare', shade=True)
facet.set(xlim=(0, train['Fare'].max()))
facet.add_legend()
plt.show()

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Fare',shade= True)
facet.set(xlim=(0, train['Fare'].max()))
facet.add_legend()
plt.xlim(0, 20)
# Out:
# (0, 20)

# %%
for dataset in train_test_data:
    dataset.loc[dataset['Fare'] <= 17, 'Fare'] = 0
    dataset.loc[(dataset['Fare'] > 17) & (dataset['Fare'] <= 30), 'Fare'] = 1
    dataset.loc[(dataset['Fare'] > 30) & (dataset['Fare'] <= 100), 'Fare'] = 2
    dataset.loc[dataset['Fare'] >= 100, 'Fare'] = 3
    
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  1.0      1      0         A/5 21171
# 1            2         1       1    1  3.0      1      0          PC 17599
# 2            3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  2.0      1      0            113803
# 4            5         0       3    0  2.0      0      0            373450
#
#    Fare Cabin  Embarked  Title
# 0   0.0   NaN         0      0
# 1   2.0   C85         1      2
# 2   0.0   NaN         0      1
# 3   2.0  C123         0      2
# 4   0.0   NaN         0      0

# %%
train.Cabin.value_counts()
# Out:
# C23 C25 C27    4
# G6             4
# B96 B98        4
# D              3
# C22 C26        3
#               ..
# D21            1
# C111           1
# C49            1
# D50            1
# D19            1
# Name: Cabin, Length: 147, dtype: int64

# %%
for dataset in train_test_data:
    dataset['Cabin'] = dataset['Cabin'].str[:1]
    
Pclass1 = train[train['Pclass'] == 1]['Cabin'].value_counts().sort_index()
Pclass2 = train[train['Pclass'] == 2]['Cabin'].value_counts().sort_index()
Pclass3 = train[train['Pclass'] == 3]['Cabin'].value_counts().sort_index()

df_cabin = pd.DataFrame({
    '1st Class': Pclass1,
    '2nd Class': Pclass2,
    '3rd Class': Pclass3
}).fillna(0)  

df_cabin.plot(kind='bar', figsize=(10, 5))
plt.title('Cabin by Pclass')
plt.ylabel('Number of Passengers')
plt.show()

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Neural Network

# %%
# Membaca dataset Titanic untuk data training dan testing
train = pd.read_csv('/kaggle/input/titanic/train.csv')
test = pd.read_csv('/kaggle/input/titanic/test.csv')

# Menghapus kolom yang tidak relevan dari dataset
# 'PassengerId', 'Name', 'Ticket', dan 'Cabin' dianggap tidak memberikan kontribusi signifikan
# dalam memprediksi apakah penumpang selamat atau tidak, sehingga di-drop.
train.drop(['PassengerId', 'Name', 'Ticket', 'Cabin'], axis=1, inplace=True)
test.drop(['Name', 'Ticket', 'Cabin'], axis=1, inplace=True)

# Mengisi nilai yang hilang pada kolom 'Age' dengan nilai median dari kolom tersebut
# karena usia penumpang penting untuk prediksi dan distribusi usia cenderung tidak simetris.
train['Age'].fillna(train['Age'].median(), inplace=True)
test['Age'].fillna(test['Age'].median(), inplace=True)

# Mengisi nilai yang hilang pada kolom 'Embarked' dengan modus (nilai yang paling sering muncul)
# karena 'Embarked' berhubungan dengan tempat naiknya penumpang yang bisa mempengaruhi keselamatan.
train['Embarked'].fillna(train['Embarked'].mode()[0], inplace=True)

# Mengisi nilai yang hilang pada kolom 'Fare' dalam dataset testing dengan median berdasarkan kelas penumpang
# karena tarif perjalanan dapat memberikan informasi tentang status sosial ekonomi penumpang.
test['Fare'].fillna(test['Fare'].median(), inplace=True)

# Menentukan kolom mana yang bersifat kategorikal dan mana yang bersifat numerik
# Kategorikal: 'Sex' dan 'Embarked' - akan diubah menjadi one-hot encoded vectors
# Numerikal: 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare' - akan dinormalisasi (standar skala)
categorical_features = ['Sex', 'Embarked']
numerical_features = ['Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# Membuat preprocessor untuk mentransformasi data
# - Numerikal: Diterapkan StandardScaler untuk normalisasi
# - Kategorikal: Diterapkan OneHotEncoder untuk mengubah kategori menjadi biner
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_features),
        ('cat', OneHotEncoder(), categorical_features)
    ])

# Memisahkan fitur (X) dan target (y) dari dataset training
X_train = train.drop("Survived", axis=1)  # X_train adalah data training tanpa kolom 'Survived'
y_train = train["Survived"]  # y_train adalah kolom 'Survived' yang menjadi target prediksi

# Menerapkan preprocessor ke data training
# Preprocessor akan mentransformasi data sesuai dengan pengaturan sebelumnya
X_train = preprocessor.fit_transform(X_train)

# Menerapkan preprocessor ke data testing (tanpa 'Survived' karena ini data prediksi)
X_test = preprocessor.transform(test)

# %%
X_train
# Out:
# array([[ 0.82737724, -0.56573646,  0.43279337, ...,  0.        ,
#          0.        ,  1.        ],
#        [-1.56610693,  0.66386103,  0.43279337, ...,  1.        ,
#          0.        ,  0.        ],
#        [ 0.82737724, -0.25833709, -0.4745452 , ...,  0.        ,
#          0.        ,  1.        ],
#        ...,
#        [ 0.82737724, -0.1046374 ,  0.43279337, ...,  0.        ,
#          0.        ,  1.        ],
#        [-1.56610693, -0.25833709, -0.4745452 , ...,  1.        ,
#          0.        ,  0.        ],
#        [ 0.82737724,  0.20276197, -0.4745452 , ...,  0.        ,
#          1.        ,  0.        ]])

# %%
X_test
# Out:
# array([[ 0.82737724,  0.39488658, -0.4745452 , ...,  0.        ,
#          1.        ,  0.        ],
#        [ 0.82737724,  1.35550962,  0.43279337, ...,  0.        ,
#          0.        ,  1.        ],
#        [-0.36936484,  2.50825727, -0.4745452 , ...,  0.        ,
#          1.        ,  0.        ],
#        ...,
#        [ 0.82737724,  0.70228595, -0.4745452 , ...,  0.        ,
#          0.        ,  1.        ],
#        [ 0.82737724, -0.18148724, -0.4745452 , ...,  0.        ,
#          0.        ,  1.        ],
#        [ 0.82737724, -0.18148724,  0.43279337, ...,  1.        ,
#          0.        ,  0.        ]])

# %%
from tensorflow.keras.layers import Dropout, Flatten, BatchNormalization, GlobalAveragePooling2D

model = Sequential([
    Dense(256, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               2816
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 44,033
# Trainable params: 44,033
# Non-trainable params: 0
# _________________________________________________________________

# %%
X_train_split, X_val, y_train_split, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

opt = tf.keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=200, batch_size=32, validation_data=(X_val, y_val))
# Out:
# Train on 891 samples, validate on 179 samples
# Epoch 1/200
# 891/891 [==============================] - 1s 1ms/sample - loss: 0.6621 - acc: 0.6240 - val_loss: 0.6426 - val_acc: 0.6760
# Epoch 2/200
# 891/891 [==============================] - 0s 85us/sample - loss: 0.6266 - acc: 0.6813 - val_loss: 0.5998 - val_acc: 0.7207
# Epoch 3/200
# 891/891 [==============================] - 0s 84us/sample - loss: 0.5944 - acc: 0.7104 - val_loss: 0.5591 - val_acc: 0.7709
# Epoch 4/200
# 891/891 [==============================] - 0s 86us/sample - loss: 0.5600 - acc: 0.7553 - val_loss: 0.5212 - val_acc: 0.7654
# Epoch 5/200
# 891/891 [==============================] - 0s 86us/sample - loss: 0.5337 - acc: 0.7587 - val_loss: 0.4913 - val_acc: 0.7654
# Epoch 6/200
# 891/891 [==============================] - 0s 86us/sample - loss: 0.5057 - acc: 0.7879 - val_loss: 0.4642 - val_acc: 0.7933
# Epoch 7/200
# 891/891 [==============================] - 0s 86us/sample - loss: 0.4781 - acc: 0.8002 - val_loss: 0.4428 - val_acc: 0.8268
# Epoch 8/200
# 891/891 [==============================] - 0s 86us/sample - loss: 0.4686 - acc: 0.8103 - val_loss: 0.4262 - val_acc: 0.8101
# Epoch 9/200
# 891/891 [==============================] - 0s 85us/sample - loss: 0.4615 - acc: 0.8092 - val_loss: 0.4142 - val_acc: 0.8212
# Epoch 10/200
# 891/891 [==============================] - 0s 87us/sample - loss: 0.4533 - acc: 0.8114 - val_loss: 0.4045 - val_acc: 0.8156
# Epoch 11/200
# 891/891 [==============================] - 0s 87us/sample - loss: 0.4458 - acc: 0.8092 - val_loss: 0.3987 - val_acc: 0.8268
# Epoch 12/200
# 891/891 [==============================] - 0s 84us/sample - loss: 0.4442 - acc: 0.8182 - val_loss: 0.3937 - val_acc: 0.8212
# Epoch 13/200
# 891/891 [==============================] - 0s 87us/sample - loss: 0.4381 - acc: 0.8126 - val_loss: 0.3892 - val_acc: 0.8156
# Epoch 14/200
# 891/891 [==============================] - 0s 85us/sample - loss: 0.4233 - acc: 0.8148 - val_loss: 0.3866 - val_acc: 0.8212
# Epoch 15/200
# 891/891 [==============================] - 0s 86us/sample - loss: 0.4308 - acc: 0.8238 - val_loss: 0.3848 - val_acc: 0.8212
# Epoch 16/200
# 891/891 [==============================] - 0s 87us/sample - loss: 0.4224 - acc: 0.8193 - val_loss: 0.3826 - val_acc: 0.8156
# Epoch 17/200
# 891/891 [==============================] - 0s 87us/sample - loss: 0.4191 - acc: 0.8182 - val_loss: 0.3794 - val_acc: 0.8156
# Epoch 18/200
# 891/891 [==============================] - 0s 86us/sample - loss: 0.4143 - acc: 0.8260 - val_loss: 0.3794 - val_acc: 0.8156
# Epoch 19/200
# 891/891 [==============================] - 0s 85us/sample - loss: 0.4152 - acc: 0.8159 - val_loss: 0.3779 - val_acc: 0.8156
# Epoch 20/200
# 891/891 [==============================] - 0s 86us/sample - loss: 0.4237 - acc: 0.8182 - val_loss: 0.3766 - val_acc: 0.8268
# Epoch 21/200
# 891/891 [==============================] - 0s 87us/sample - loss: 0.4212 - acc: 0.8182 - val_loss: 0.3768 - val_acc: 0.8156
# Epoch 22/200
# 891/891 [==============================] - 0s 89us/sample - loss: 0.4217 - acc: 0.8159 - val_loss: 0.3758 - val_acc: 0.8268
# Epoch 23/200
# 891/891 [==============================] - 0s 87us/sample - loss: 0.
200
# 891/891 [==============================] - 0s 84us/sample - loss: 0.3329 - acc: 0.8620 - val_loss: 0.3026 - val_acc: 0.8827
# Epoch 180/200
# 891/891 [==============================] - 0s 83us/sample - loss: 0.3304 - acc: 0.8620 - val_loss: 0.3011 - val_acc: 0.8883
# Epoch 181/200
# 891/891 [==============================] - 0s 85us/sample - loss: 0.3302 - acc: 0.8653 - val_loss: 0.2978 - val_acc: 0.8827
# Epoch 182/200
# 891/891 [==============================] - 0s 86us/sample - loss: 0.3338 - acc: 0.8631 - val_loss: 0.2965 - val_acc: 0.8883
# Epoch 183/200
# 891/891 [==============================] - 0s 85us/sample - loss: 0.3290 - acc: 0.8676 - val_loss: 0.2965 - val_acc: 0.8827
# Epoch 184/200
# 891/891 [==============================] - 0s 85us/sample - loss: 0.3412 - acc: 0.8575 - val_loss: 0.2963 - val_acc: 0.8939
# Epoch 185/200
# 891/891 [==============================] - 0s 86us/sample - loss: 0.3313 - acc: 0.8631 - val_loss: 0.2986 - val_acc: 0.8827
# Epoch 186/200
# 891/891 [==============================] - 0s 87us/sample - loss: 0.3294 - acc: 0.8687 - val_loss: 0.2946 - val_acc: 0.8827
# Epoch 187/200
# 891/891 [==============================] - 0s 87us/sample - loss: 0.3354 - acc: 0.8687 - val_loss: 0.2958 - val_acc: 0.8827
# Epoch 188/200
# 891/891 [==============================] - 0s 86us/sample - loss: 0.3296 - acc: 0.8631 - val_loss: 0.2949 - val_acc: 0.8883
# Epoch 189/200
# 891/891 [==============================] - 0s 85us/sample - loss: 0.3280 - acc: 0.8597 - val_loss: 0.2933 - val_acc: 0.8939
# Epoch 190/200
# 891/891 [==============================] - 0s 83us/sample - loss: 0.3259 - acc: 0.8765 - val_loss: 0.2944 - val_acc: 0.8883
# Epoch 191/200
# 891/891 [==============================] - 0s 84us/sample - loss: 0.3312 - acc: 0.8642 - val_loss: 0.2965 - val_acc: 0.8883
# Epoch 192/200
# 891/891 [==============================] - 0s 84us/sample - loss: 0.3327 - acc: 0.8631 - val_loss: 0.2937 - val_acc: 0.8827
# Epoch 193/200
# 891/891 [==============================] - 0s 85us/sample - loss: 0.3287 - acc: 0.8709 - val_loss: 0.2955 - val_acc: 0.8883
# Epoch 194/200
# 891/891 [==============================] - 0s 84us/sample - loss: 0.3314 - acc: 0.8687 - val_loss: 0.2951 - val_acc: 0.8883
# Epoch 195/200
# 891/891 [==============================] - 0s 83us/sample - loss: 0.3309 - acc: 0.8608 - val_loss: 0.2926 - val_acc: 0.8883
# Epoch 196/200
# 891/891 [==============================] - 0s 85us/sample - loss: 0.3250 - acc: 0.8754 - val_loss: 0.2948 - val_acc: 0.8883
# Epoch 197/200
# 891/891 [==============================] - 0s 90us/sample - loss: 0.3264 - acc: 0.8631 - val_loss: 0.2937 - val_acc: 0.8883
# Epoch 198/200
# 891/891 [==============================] - 0s 121us/sample - loss: 0.3276 - acc: 0.8664 - val_loss: 0.2928 - val_acc: 0.8939
# Epoch 199/200
# 891/891 [==============================] - 0s 87us/sample - loss: 0.3319 - acc: 0.8676 - val_loss: 0.2954 - val_acc: 0.8827
# Epoch 200/200
# 891/891 [==============================] - 0s 87us/sample - loss: 0.3172 - acc: 0.8676 - val_loss: 0.2959 - val_acc: 0.8883

# %%
train_loss, train_accuracy = model.evaluate(X_train, y_train, verbose=0)

val_loss = history.history['val_loss'][-1]
val_accuracy = history.history['val_acc'][-1]

print(f"Training Loss: {train_loss:.4f}, Training Accuracy: {train_accuracy:.4f}")
print(f"Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}")
# Out:
# Training Loss: 0.3134, Training Accuracy: 0.8709
# Validation Loss: 0.2959, Validation Accuracy: 0.8883

# %%
plt.figure(figsize=(12, 6))
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
y_pred_val = model.predict(X_val)
y_pred_val = (y_pred_val > 0.5).astype(int).flatten()  

conf_matrix = confusion_matrix(y_val, y_pred_val)
class_report = classification_report(y_val, y_pred_val)

print("\nClassification Report - Neural Network:")
print(class_report)

# Plot Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix - Neural Network')
plt.show()
# Out:
# Classification Report - Neural Network:
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.91       105
#            1       0.90      0.82      0.86        74
#
#     accuracy                           0.89       179
#    macro avg       0.89      0.88      0.88       179
# weighted avg       0.89      0.89      0.89       179

# %% [markdown]
# ## Machine Learning - SVM

# %%
X_train_split, X_val, y_train_split, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

param_grid = {
    'C': [0.1, 1, 10, 100],
    'gamma': [1, 0.1, 0.01, 0.001],
    'kernel': ['linear', 'poly', 'sigmoid']
}

svm_model = SVC(random_state=101)
grid_search = GridSearchCV(svm_model, param_grid, refit=True, cv=5, verbose=0)
grid_search.fit(X_train_split, y_train_split)

best_svm_model = grid_search.best_estimator_
y_pred = best_svm_model.predict(X_val)

# %%
accuracy = accuracy_score(y_val, y_pred)
y_test_pred = best_svm_model.predict(X_test)

conf_matrix = confusion_matrix(y_val, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False, annot_kws={"size": 16})
plt.title('Confusion Matrix - SVM:', fontsize=20)
plt.xlabel('Predicted', fontsize=16)
plt.ylabel('Actual', fontsize=16)
plt.show()

class_report = classification_report(y_val, y_pred)
print("Classification Report - SVM:")
print(class_report)

test_predictions = best_svm_model.predict(X_test)
submission = pd.DataFrame({
    "PassengerId": test["PassengerId"],
    "Survived": test_predictions
})
# Out:
# Classification Report - SVM:
#               precision    recall  f1-score   support
#
#            0       0.81      0.86      0.83       105
#            1       0.78      0.72      0.75        74
#
#     accuracy                           0.80       179
#    macro avg       0.80      0.79      0.79       179
# weighted avg       0.80      0.80      0.80       179

# %%
# Menampilkan parameter terbaik untuk model SVM
print("Best parameters for SVM:", grid_search.best_params_)
# Out:
# Best parameters for SVM: {'C': 10, 'gamma': 0.1, 'kernel': 'poly'}

# %% [markdown]
# ## Machine Learning - KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_param_grid = {
    'n_neighbors': range(1, 100),
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan', 'minkowski']
}

knn_model = KNeighborsClassifier()
knn_grid_search = GridSearchCV(knn_model, knn_param_grid, refit=True, cv=5, verbose=0)
knn_grid_search.fit(X_train, y_train)

best_knn_model = knn_grid_search.best_estimator_
y_pred_knn = best_knn_model.predict(X_val)

# %%
knn_accuracy = accuracy_score(y_val, y_pred_knn)
print(classification_report(y_val, y_pred_knn))

conf_matrix_knn = confusion_matrix(y_val, y_pred_knn)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_knn, annot=True, fmt='d', cmap='Blues', cbar=False, annot_kws={"size": 16})
plt.title('Confusion Matrix - KNN', fontsize=20)
plt.xlabel('Predicted', fontsize=16)
plt.ylabel('Actual', fontsize=16)
plt.show()

test_predictions_knn = best_knn_model.predict(X_test)

submission_knn = pd.DataFrame({
    "PassengerId": test["PassengerId"],
    "Survived": test_predictions_knn
})
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87       105
#            1       0.85      0.76      0.80        74
#
#     accuracy                           0.84       179
#    macro avg       0.84      0.83      0.84       179
# weighted avg       0.84      0.84      0.84       179

# %%
# Menampilkan parameter terbaik untuk model KNN
print("Best parameters for KNN:", knn_grid_search.best_params_)
# Out:
# Best parameters for KNN: {'metric': 'manhattan', 'n_neighbors': 12, 'weights': 'uniform'}

# %%
results_df = pd.DataFrame({
    'Model': ['Neural Network', 'SVM', 'KNN'],
    'Training Accuracy (%)': [train_accuracy * 100, grid_search.best_score_ * 100, knn_grid_search.best_score_ * 100],
    'Test Accuracy (%)': [history.history['val_acc'][-1] * 100, accuracy * 100, knn_accuracy * 100]
})

results_df = results_df.sort_values(by='Test Accuracy (%)', ascending=False).reset_index(drop=True)
results_df
# Out:
#             Model  Training Accuracy (%)  Test Accuracy (%)
# 0  Neural Network              87.093157          88.826817
# 1             KNN              82.042649          84.357542
# 2             SVM              81.320225          79.888268
